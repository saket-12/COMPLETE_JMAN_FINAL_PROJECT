# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DataProjects 1.csv")

# %%
df
# Out:
#                            _id                    userId  \
# 0     66123929c478ba97b06a87b5  6612382ec478ba97b06a6c5d
# 1     66123929c478ba97b06a87b6  6612382ec478ba97b06a6c5d
# 2     66123929c478ba97b06a87b7  6612382ec478ba97b06a6c5e
# 3     66123929c478ba97b06a87b8  6612382ec478ba97b06a6c5e
# 4     66123929c478ba97b06a87b9  6612382ec478ba97b06a6c5f
# ...                        ...                       ...
# 1995  6612396ec478ba97b06a8f80  6612386ac478ba97b06a7042
# 1996  6612396ec478ba97b06a8f81  6612386ac478ba97b06a7043
# 1997  6612396ec478ba97b06a8f82  6612386ac478ba97b06a7043
# 1998  6612396ec478ba97b06a8f83  6612386ac478ba97b06a7044
# 1999  6612396ec478ba97b06a8f84  6612386ac478ba97b06a7044
#
#                  projectName  \
# 0          Whole face System
# 1        Coach around System
# 2         Card expert System
# 3        Next include System
# 4         Up election System
# ...                      ...
# 1995  Imagine mission System
# 1996        Do minute System
# 1997      Many decide System
# 1998       Detail gas System
# 1999      Much spring System
#
#                                             description  totalHoursWorked  \
# 0     Home something somebody stuff team feeling. De...               106
# 1     Another still forward early class address ever...               100
# 2     Boy water real adult cold and. Central word we...               144
# 3     Whom herself mean popular career list factor. ...                73
# 4     Night course eight vote production field campa...               142
# ...                                                 ...               ...
# 1995  Responsibility blue despite. Remember try word...                75
# 1996  Exist direction clear director ago. Care will ...               133
# 1997  Southern establish treat friend. Black either ...               146
# 1998  Teacher operation pattern month care step term...               135
# 1999  One their PM employee factor fill fly. Confere...                64
#
#         techUsed performance  isApproved       approvedBy      Domain
# 0       Power BI        good        True   David Stephens        Data
# 1         Python        good        True       Linda Dunn        Data
# 2     AWS Lambda        good        True    Lynn Schaefer  Full Stack
# 3     Javascript        good        True  Brittany Flores  Full Stack
# 4        Alteryx     average        True  Brooke Hamilton  Full Stack
# ...          ...         ...         ...              ...         ...
# 1995       React        good        True    Maria Jimenez  Full Stack
# 1996  AWS Lambda     average        True  Christy Simmons        Data
# 1997  AWS Lambda   excellent        True   Donald Bennett  Full Stack
# 1998       React   excellent        True  Jacqueline Rose        Data
# 1999      Python     average        True  Jasmine Ellison        Data
#
# [2000 rows x 10 columns]

# %%
project_names = [
    "CodeCrafter", "PixelForge", "WebWarp", "AppArchitect", "StackSavvy",
    "CodeCanvas", "DevDynamo", "ByteBridge", "PixelPulse", "TechTrek",
    "AppAlchemy", "WebWeave", "CodeCraftsman", "StackStream", "DevForge",
    "ByteBlast", "PixelPioneer", "TechTerra", "WebWizardry", "CodeCompass",
    "DataForge", "StreamSculpt", "DataMason", "PipelinePro", "DataDynamo",
    "StreamSmith", "DataFlowX", "ETLGenius", "DataPulse", "FlowForge",
    "DataCraftsman", "PipelinePioneer", "DataSculptor", "StreamSavvy",
    "DataWarp", "FlowFlex", "ETLArchitect", "DataForge", "StreamBuilder",
    "DataPulse", "Insightify", "AnalyticaPro", "DataVista", "TrendTrack",
    "AnalyzeRight", "DataScope", "InsightForge", "AnalyticsPulse", "TrendTrek",
    "DataNexus", "InsightGenius", "AnalyzeAll", "DataHorizon", "TrendSpotter",
    "InsightSavvy", "AnalytixPro", "DataWave", "TrendTerra", "InsightStream",
    "AnalyzeWise", "DataStack", "DataDriven", "FullDataForge", "CodeCraftsmanX",
    "StackStream", "DataDevForge", "FullStackInsight", "ByteBridgeX",
    "DataSavvyStack", "StackForge", "DataCraftsmanX", "FullTechTrek", "StreamStack",
    "DataByteForge", "StackSculptor", "InsightStack", "FullAnalytica", "DataTrekker",
    "CodeCraftsmanInsight", "AnalyzeByte", "StackScope", "InsightForgeX",
    "FullTrendTrack", "DataCraftsmanInsight", "AnalyzeStack", "StackSavvyInsight",
    "InsightStreamX", "FullDataNexus", "AnalyzeStream", "StackSpotter", "DataStacker",
    "FullDataInsight", "CodeCraftsmanData", "InsightBuilder", "DataForgeX",
    "FullStreamSculpt", "ByteBridgeData", "DataSavvyInsight", "FullInsightForge",
    "StackCraftsmanData"
]

# %%
import random

# %%
random.shuffle(project_names)

# %%
df['projectName'] = random.choices(project_names, k=len(df))

# %%
columns_drop = ['_id' , 'description' , 'isApproved' , 'approvedBy']

# %%
df = df.drop(columns=columns_drop , axis=1)

# %%
df
# Out:
#                         userId           projectName  totalHoursWorked  \
# 0     6612382ec478ba97b06a6c5d             TechTerra               106
# 1     6612382ec478ba97b06a6c5d            StackForge               100
# 2     6612382ec478ba97b06a6c5e          InsightStack               144
# 3     6612382ec478ba97b06a6c5e            TrendTerra                73
# 4     6612382ec478ba97b06a6c5f  DataCraftsmanInsight               142
# ...                        ...                   ...               ...
# 1995  6612386ac478ba97b06a7042            TrendTrack                75
# 1996  6612386ac478ba97b06a7043         InsightStream               133
# 1997  6612386ac478ba97b06a7043           DataStacker               146
# 1998  6612386ac478ba97b06a7044           StreamStack               135
# 1999  6612386ac478ba97b06a7044     StackSavvyInsight                64
#
#         techUsed performance      Domain
# 0       Power BI        good        Data
# 1         Python        good        Data
# 2     AWS Lambda        good  Full Stack
# 3     Javascript        good  Full Stack
# 4        Alteryx     average  Full Stack
# ...          ...         ...         ...
# 1995       React        good  Full Stack
# 1996  AWS Lambda     average        Data
# 1997  AWS Lambda   excellent  Full Stack
# 1998       React   excellent        Data
# 1999      Python     average        Data
#
# [2000 rows x 6 columns]

# %%
df.to_csv('updatedProjects.csv')
