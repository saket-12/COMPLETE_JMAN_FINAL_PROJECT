# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DataCertificates 1.csv")

# %%
df
# Out:
#                            _id                    userId certificateName  \
# 0     661238cfc478ba97b06a7bfd  6612382ec478ba97b06a6c5d         Quonkle
# 1     661238cfc478ba97b06a7bfe  6612382ec478ba97b06a6c5d         Snizzle
# 2     661238cfc478ba97b06a7bff  6612382ec478ba97b06a6c5d          Zibble
# 3     661238cfc478ba97b06a7c00  6612382ec478ba97b06a6c5e     Quiffleflap
# 4     661238cfc478ba97b06a7c01  6612382ec478ba97b06a6c5e      Doodlewump
# ...                        ...                       ...             ...
# 2995  6612390dc478ba97b06a87b0  6612386ac478ba97b06a7043        Quonklet
# 2996  6612390dc478ba97b06a87b1  6612386ac478ba97b06a7043         Blibber
# 2997  6612390dc478ba97b06a87b2  6612386ac478ba97b06a7044     Snizzleblat
# 2998  6612390dc478ba97b06a87b3  6612386ac478ba97b06a7044         Blimble
# 2999  6612390dc478ba97b06a87b4  6612386ac478ba97b06a7044         Quackle
#
#                   organization  isApproved        approvedBy certificateFile
# ...

# %%
columns_to_drop = ['_id' , 'organization' , 'isApproved' , 'approvedBy' , 'certificateFile']

# %%
df = df.drop(columns=columns_to_drop, axis=1)

# %%
df
# Out:
#                         userId certificateName
# 0     6612382ec478ba97b06a6c5d         Quonkle
# 1     6612382ec478ba97b06a6c5d         Snizzle
# 2     6612382ec478ba97b06a6c5d          Zibble
# 3     6612382ec478ba97b06a6c5e     Quiffleflap
# 4     6612382ec478ba97b06a6c5e      Doodlewump
# ...                        ...             ...
# 2995  6612386ac478ba97b06a7043        Quonklet
# 2996  6612386ac478ba97b06a7043         Blibber
# 2997  6612386ac478ba97b06a7044     Snizzleblat
# 2998  6612386ac478ba97b06a7044         Blimble
# 2999  6612386ac478ba97b06a7044         Quackle
#
# [3000 rows x 2 columns]

# %%
df.to_csv('updatedCertificates.csv')
